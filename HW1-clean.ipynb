# %% [markdown]
# # Cleaned notebook
#
# This cleaned copy removes the `metadata.widgets` section from the original HW1.ipynb so GitHub/nbconvert can render it.
#
# Original file (unchanged) is at: https://github.com/ApexShadow28/GenAI/blob/2b5feac38c5351213765dfae7416eee66490f8ce/HW1.ipynb
#
# If you want a full cleaned copy that preserves all cells but strips outputs and widget metadata, tell me and I will replace this file with that version instead.
